# %% [markdown]
# Limitations of the first approach are as follows -
#
# 1. Need to convert data to a list fomat. When we observe real life store data, it has thousands of products. Thus, computation becomes expensive.
# 2. The Apyori package has not received recent updates in past few years.
# 3. Results need to be formatted properly. This also requires additional computation.
#
# Therefore, we adopt the mlxtend package -
#
# 1. The mlxtend package uses two-way based approach which generates frequent itemset and association rules easily.
# 2. The mlxtend package receives proper community support.

# %%
'''
load apriori and association package from mlxtend.
Using a different dataset because mlxtend requires data in the below format.

             itemname  apple banana grapes
transaction  1            0    1     1
             2            1    0     1
             3            1    0     0
             4            0    1     0

'''

# Importing the necessary packages

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# Load the data.csv dataset

# %%
# List the countries

# %%
# Extract data only for Spain

# %%
# Check for additonal spaces in description and remove them

# %%
# Check if transaction quantity is negative and remove those

# %%
# List any 5 rows from the data you have prepared earlier

# %%
# Convert your data to pivot table format with summed up quantities. Fill with 0 if any NaN values are found

# %%
# Write a function to find whether an item is taken or not. If user has taken that item mark as 1, else mark as 0
# Explore the applymap() function

# %%
# Verify the correctness of the statement

# %%
# Remove postage item as it is just a seal which almost all transactions contain

# %%
# Call apriori function and pass minimum support as 7% and store result in frequent_itemsets

# %%
# We have association rules which need to put on frequent itemset. Do the same using a lift threshold of 1

# %%
# Rename the lhs column as antecedents and rhs as consequents

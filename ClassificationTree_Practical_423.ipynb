# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder

# %%
from ISLP import load_data

# %%
car = load_data('carseats')

# %%
car.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
car['Y'] = (car['Sales'] >= 8).astype(int)

# %%
car['ShelveLoc_enc'] = LabelEncoder().fit_transform(car['ShelveLoc'])
car['Urban_enc'] = LabelEncoder().fit_transform(car['Urban'])
car['US_enc'] = LabelEncoder().fit_transform(car['US'])

# %%
car.drop(['Sales','ShelveLoc','Urban', 'US'], axis=1, inplace=True)

# %%
car.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price  Age  Education  Y  \
# 0        138      73           11         276    120   42         17  1
# 1        111      48           16         260     83   65         10  1
# 2        113      35           10         269     80   59         12  1
# 3        117     100            4         466     97   55         14  0
# 4        141      64            3         340    128   38         13  0
#
#    ShelveLoc_enc  Urban_enc  US_enc
# 0              0          1       1
# 1              1          1       1
# 2              2          1       1
# 3              2          1       1
# 4              0          1       0

# %%
Y = car['Y']
X = car.drop(['Y'], axis=1)

# %%
X.shape, Y.shape
# Out:
# ((400, 10), (400,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=40)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((300, 10), (100, 10), (300,), (100,))

# %% [markdown]
# ### Fully Grown Tree - Unpruned

# %%
dt = DecisionTreeClassifier(random_state=0)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
print('Results for the fitted Decision Tree')
trn_acc = dt.score(X_train,y_train)
tst_acc = dt.score(X_test,y_test)
print('Train Acc: ', trn_acc)
print('test Acc: ', tst_acc)
# Out:
# Results for the fitted Decision Tree
# Train Acc:  1.0
# test Acc:  0.73

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred_unpruned = dt.predict(X_test)
cm_unpruned = confusion_matrix(y_test,y_pred_unpruned)
disp_un = ConfusionMatrixDisplay(confusion_matrix = cm_unpruned)
disp_un.plot()

# %%
test_acc_unpruned = np.sum(np.diag(cm_unpruned))/np.sum(cm_unpruned)
test_acc_unpruned
# Out:
# np.float64(0.73)

# %%
# Accuracy= Number of correct predictions/Total number of sample (model.score() calculates this for all classifiers and also
# same for logistic regression.

# %%
# plt.figure(figsize=(15,15))
# print(plot_tree(dt, filled=True, fontsize=5))

# %%
dt.tree_.max_depth, dt.tree_.node_count
# Out:
# (10, 109)

# %%
path = dt.cost_complexity_pruning_path(X_train, y_train)

# %%
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
plt.plot(ccp_alphas, impurities, marker = 'o')
plt.xlabel(r'$\alpha$', fontsize = 15)
plt.ylabel('Impurities', fontsize = 15)
# Out:
# Text(0, 0.5, 'Impurities')

# %%
ccp_alphas
# Out:
# array([0.        , 0.00277778, 0.003     , 0.00307692, 0.00316667,
#        0.00324786, 0.00327044, 0.0037037 , 0.00411523, 0.00415304,
#        0.00421053, 0.00444444, 0.00444444, 0.00490909, 0.00545455,
#        0.00573016, 0.00591803, 0.00636169, 0.00646465, 0.0069697 ,
#        0.00755245, 0.00888889, 0.01061752, 0.01128205, 0.01309091,
#        0.01326522, 0.01944883, 0.02292407, 0.02464103, 0.02860867,
#        0.04200003, 0.04667972])

# %%
ccp_alphas = np.unique(ccp_alphas)

# %%
ccp_alphas = ccp_alphas[:-1]

# %%
clfs = []
for alpha in ccp_alphas:
    clf = DecisionTreeClassifier(ccp_alpha=alpha, random_state=0)
    clf.fit(X_train, y_train)
    clfs.append(clf)

# %%
# Average CV accuracy results on the train set
cv_scores = [np.mean(cross_val_score(clf, X_train, y_train, cv=5)) for clf in clfs]

# %%
plt.plot(ccp_alphas, cv_scores, marker='o')
plt.xlabel(r'$\alpha$', fontsize = 15)
plt.ylabel('Avg CV Accuracies', fontsize = 15)
plt.show()

# %%
ccp_alphas[np.argmax(cv_scores)]
# Out:
# np.float64(0.006969696969696968)

# %% [markdown]
# ### Pruned Tree

# %%
best_tree = DecisionTreeClassifier(ccp_alpha=0.006970, random_state=0)
best_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.00697, random_state=0)

# %%
print('Results for the final fitted Decision Tree')
trn_acc = best_tree.score(X_train,y_train)
tst_acc = best_tree.score(X_test,y_test)
print('Train Acc: ', trn_acc)
print('test Acc: ', tst_acc)
# Out:
# Results for the final fitted Decision Tree
# Train Acc:  0.9033333333333333
# test Acc:  0.76

# %%
best_tree.tree_.max_depth, best_tree.tree_.node_count
# Out:
# (7, 35)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred_pruned = best_tree.predict(X_test)
cm_pruned = confusion_matrix(y_test,y_pred_pruned)
dispp = ConfusionMatrixDisplay(confusion_matrix=cm_pruned)
dispp.plot()

# %%
test_acc_pruned = np.sum(np.diag(cm_pruned))/np.sum(cm_pruned)

# %%
test_acc_pruned
# Out:
# np.float64(0.76)

# %%
node_counts = [clf.tree_.node_count for clf in clfs]
depths = [clf.tree_.max_depth for clf in clfs]

# %%
plt.plot(ccp_alphas, node_counts, marker='o')
plt.xlabel(r'$\alpha$', fontsize = 15)
plt.ylabel('No. of nodes', fontsize = 15)
plt.show()

# %%
plt.plot(ccp_alphas, depths, marker='o')
plt.xlabel(r'$\alpha$', fontsize = 15)
plt.ylabel('depths', fontsize = 15)
plt.show()

# %%
train_scores = [clf.score(X_train, y_train) for clf in clfs]
test_scores = [clf.score(X_test, y_test) for clf in clfs]

plt.xlabel("alpha")
plt.ylabel("accuracy")
plt.title("Accuracy vs alpha for training and testing sets")
plt.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
plt.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
plt.legend()
plt.show()

# %%
pd.DataFrame({'Train acc': train_scores,
               'Test acc': test_scores,
               'Nodes': node_counts,
               'Depth': depths,
               'ccp_alphas': ccp_alphas,
               'CV_acc': cv_scores})
# Out:
#     Train acc  Test acc  Nodes  Depth  ccp_alphas    CV_acc
# 0    1.000000      0.73    109     10    0.000000  0.736667
# 1    0.996667      0.73    105     10    0.002778  0.736667
# 2    0.993333      0.73    101     10    0.003000  0.736667
# 3    0.990000      0.73     97     10    0.003077  0.736667
# 4    0.986667      0.72     93     10    0.003167  0.736667
# 5    0.983333      0.72     89     10    0.003248  0.736667
# 6    0.980000      0.72     85     10    0.003270  0.736667
# 7    0.973333      0.75     79     10    0.003704  0.743333
# 8    0.966667      0.75     73     10    0.004115  0.766667
# 9    0.960000      0.76     67     10    0.004153  0.766667
# 10   0.953333      0.77     61     10    0.004211  0.766667
# 11   0.943333      0.77     55      8    0.004444  0.766667
# 12   0.940000      0.77     53      8    0.004909  0.766667
# 13   0.933333      0.77     49      8    0.005455  0.766667
# 14   0.930000      0.77     47      8    0.005730  0.773333
# 15   0.926667      0.78     45      8    0.005918  0.773333
# 16   0.920000      0.78     41      8    0.006362  0.766667
# 17   0.916667      0.79     39      8    0.006465  0.766667
# 18   0.903333      0.76     35      7    0.006970  0.780000
# 19   0.896667      0.76     33      7    0.007552  0.776667
# 20   0.890000      0.76     31      7    0.008889  0.740000
# 21   0.870000      0.76     25      7    0.010618  0.743333
# 22   0.863333      0.73     23      6    0.011282  0.736667
# 23   0.850000      0.70     21      6    0.013091  0.733333
# 24   0.830000      0.72     17      6    0.013265  0.733333
# 25   0.800000      0.75     13      4    0.019449  0.726667
# 26   0.790000      0.79     11      4    0.022924  0.703333
# 27   0.773333      0.79      9      4    0.024641  0.686667
# 28   0.690000      0.76      5      2    0.028609  0.636667
# 29   0.600000      0.52      3      1    0.042000  0.576667

# %% [markdown]
# ### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
model.score(X_train,y_train)
# Out:
# 0.8133333333333334

# %%
model.score(X_test,y_test)
# Out:
# 0.85

# %%
d = {'Train Accuracy':[1.0,0.90,0.81],
     'Test Accuracy':[0.73,0.76,0.85]   
}

pd.DataFrame(d,index=['Unpruned Tree','Pruned Tree','Logistic Regression'])
# Out:
#                      Train Accuracy  Test Accuracy
# Unpruned Tree                  1.00           0.73
# Pruned Tree                    0.90           0.76
# Logistic Regression            0.81           0.85

# %%
# So we can see that logistic regression performs better than the other 2. The pruned tree performs better
# than the unpruned tree in terms of the test accuracy.

# %%
# Confusion matrix

y_test_pred_log = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,y_test_pred_log)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
cm
# Out:
# array([[57,  9],
#        [ 6, 28]])

# %%
test_acc_cm = np.sum(np.diag(cm))/np.sum(cm)

# %%
test_acc_cm
# Out:
# np.float64(0.85)

# %%
np.sum(np.diag(cm))
# Out:
# np.int64(85)
